# %%
import os
os.chdir('../..')
print(os.getcwd())
# Out:
# /home/jsanz/git/echo

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import pandas
import re

from utils.util_pandas import PandasDF, create_agent_from_row

np.random.seed(7)
torch.manual_seed(7)

# %%
# Load run results
HOME_DIR = './data'
PANDAS_DATAFRAME_FILENAME = HOME_DIR + '/df.xls'
RESULTS_DIR = HOME_DIR + '/results'
RESULTS_KEY = 'results_filename'
MODELS_DIR = HOME_DIR + '/saved_models'
MODELS_KEY = 'model_filename'

DF = PandasDF(HOME_DIR=HOME_DIR, RESULTS_DIR=RESULTS_DIR, MODELS_DIR=MODELS_DIR,
              PANDAS_DATAFRAME_FILENAME=PANDAS_DATAFRAME_FILENAME,
              RESULTS_KEY=RESULTS_KEY, MODELS_KEY=MODELS_KEY)

# %%
DF.df.keys()
# Out:
# Index(['epochs', 'learner', 'inner_batch_size', 'std_explore',
#        'restrict_energy', 'inner_steps', 'stepsize_meta', 'SNR_db',
#        'bits_per_symbol', 'optimizer', 'first_order', 'seed', 'model',
#        'hidden_layers', 'nshots', 'meta-alg', 'stepsize_inner',
#        'outer_batch_size', 'ntasks', 'loss_function', 'model_filename',
#        'results_filename'],
#       dtype='object')

# %%
print("Inner steps", DF.df['inner_steps'].unique())
print("Length", len(DF.df))
# Out:
# Inner steps ['None' 5 10]
# Length 53

# %% [markdown]
# ## Double checking 'best' results

# %% [raw]
# query = {'bits_per_symbol': 2,
#  'inner_batch_size': 256,
#  'outer_batch_size': 1024,
#  'stepsize_inner': 0.1,
#  'stepsize_meta': 0.2,
#  'inner_steps': 5,
#  'optimizer': 'sgd',
#  'ntasks': 16,
# #  'first_order': True,
# #  'epochs': 5000,
#  'hidden_layers': [50, 50],
#  'std_explore': 0.3}
# response = DF.search_rows(query)
#
# if len(response) > 0:
#     compute_test_bers(response, query)

# %% [raw]
# query = {'bits_per_symbol': 4,
#  'inner_batch_size': 256,
#  'outer_batch_size': 1024,
#  'stepsize_inner': 0.1,
#  'stepsize_meta': 0.2,
#  'inner_steps': 5,
#  'optimizer': 'sgd',
#  'ntasks': 16,
# #  'first_order': True,
# #  'epochs': 5000,
#  'hidden_layers': [100, 100],
#  'std_explore': 0.3}
# response = DF.search_rows(query)
# if len(response) > 0:
#     compute_test_bers(response, query)

# %% [markdown]
# ## Loading the models

# %%
from utils.util_lookup_table import BER_lookup_table
from models.demodulator import Demodulator
from models.demodulator_models.Classic import Classic as ClassicDemod
from models.modulator_models.MAMLNeural import MAMLNeural
from models.maml_modulator import MAMLModulatorLossPassing

def test_mod_losspassing(mod, demods, nshots, train_batch_size, test_batch_size, step_size, num_trials = 1, test_bers = [1e-5, 1e-2]):   
    ber_array_dict = {}
    constellations = []
    for demod in demods:
        for trial in range(num_trials):
#         mod.update_test_old(demod, nshots=16, batch_size=32, step_size=1e-2)
            bers, constellation = mod.update_test_dev(demod, nshots=nshots, train_batch_size=train_batch_size, test_batch_size = test_batch_size, step_size=step_size, test_bers = test_bers)
            
            for key in bers:
                if key not in ber_array_dict:
                    ber_array_dict[key] = []
                ber_array_dict[key].append(bers[key])
            constellations.append(constellation)
                
    for key in ber_array_dict:
        ber_array_dict[key] = np.array(ber_array_dict[key])
#         print(ber_array_dict[key].shape) 
    #Get order statistics
    return ber_array_dict, constellations

def plot_test_bers(maml_ber_array_dict, random_ber_array_dict, test_bers):
    sorted_bers = -np.sort(-np.array(test_bers))          
    for k,key in enumerate(sorted(list(maml_ber_array_dict.keys()))):      
        plt.gcf().clear()
        fig = plt.figure(figsize=(8,6))
        plt.rcParams.update({'font.size': 18})
        ax = fig.add_subplot(111)
        plt.title('BER, SNR_db = {:.1f}'.format(key))
          
        #MAML      
        ber_array_dict = maml_ber_array_dict
        ber_array = ber_array_dict[key]
        
        avg_bers = np.mean(ber_array, 0)
        median_bers = np.median(ber_array, 0)
        top_10_bers = np.percentile(ber_array,q = 90, axis = 0)
        bot_10_bers = np.percentile(ber_array,q = 10, axis = 0)       
 
        ax.plot(median_bers, 'o--', label = 'MAML')
        yerr =top_10_bers - bot_10_bers
        ax.errorbar(x = np.arange(len(median_bers)), y = median_bers, yerr = yerr)
        
        #Random
        ber_array_dict = random_ber_array_dict
        ber_array = ber_array_dict[key]
        
        avg_bers = np.mean(ber_array, 0)
        median_bers = np.median(ber_array, 0)
        top_10_bers = np.percentile(ber_array,q = 90, axis = 0)
        bot_10_bers = np.percentile(ber_array,q = 10, axis = 0)       

     
        ax.plot(median_bers, 'o--', label = 'Random')
        yerr =top_10_bers - bot_10_bers
        ax.errorbar(x = np.arange(len(median_bers)), y = median_bers, yerr = yerr)
 
        #Baseline              
        base_ber = sorted_bers[k]
        ax.plot(np.arange(len(median_bers)),base_ber*np.ones_like(median_bers), label = 'Baseline')
        
        
        handles, labels = ax.get_legend_handles_labels()
        lgd = ax.legend(handles, labels, loc='center right', bbox_to_anchor=(1.73,0.73))
        ax.grid(True)
#         ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlabel('nshots')
        ax.set_ylabel('BER')
        plt.show()

        
def compute_test_bers(response, query):
    ntasks = 2
    nshots = 30
    num_trials = 10
    test_batch_size = int(10000)
    test_bers = [1e-3, 1e-2]
    
    for r in range(len(response)):
        mod = create_agent_from_row(response.iloc[r], MAMLModulatorLossPassing, MAMLNeural, 
                                    {"device": "cpu"})
        print("Parameters:")
        print(response.iloc[r])
        
        bits_per_symbol = response.iloc[r]['bits_per_symbol']
        demods = [Demodulator(model=ClassicDemod, bits_per_symbol=bits_per_symbol, rotation=rot, verbose = True)  for rot in np.random.uniform(0, 2*np.pi, ntasks)]
        
        train_batch_size = response.iloc[r]['inner_batch_size']
        step_size = response.iloc[r]['stepsize_inner']

        maml_ber_array_dict, maml_constellations = test_mod_losspassing(test_bers = test_bers, mod=mod, demods=demods, nshots=nshots, train_batch_size=train_batch_size, test_batch_size = test_batch_size, step_size=step_size, num_trials = num_trials)
        
        # Randomize model weights
        mod.model._init_weights()
        random_ber_array_dict, random_constellations = test_mod_losspassing(test_bers = test_bers, mod=mod, demods=demods, nshots=nshots, train_batch_size=train_batch_size, test_batch_size = test_batch_size, step_size=step_size, num_trials = num_trials)
        plt.scatter(maml_constellations[0][:, 0], maml_constellations[0][:, 1])
        plt.show()
        #TODO some filtering to get best hyperparameters
        plot_test_bers(maml_ber_array_dict, random_ber_array_dict, test_bers)

bps = 2
# snr = 12
# sm = 1e-2
query = {'bits_per_symbol': bps, 'learner': 'modulator'}
response = DF.search_rows(query)
print("{} results found".format(len(response)))
compute_test_bers(response, query)
# Out:
# 18 results found
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                     0.3
# restrict_energy                                   1
# inner_steps                                       5
# stepsize_meta                                  0.01
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                   False
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                 0.01
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_1.npy
# results_filename       ./data/results/results_1.npy
# Name: 1, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                     0.3
# restrict_energy                                   1
# inner_steps                                      10
# stepsize_meta                                  0.01
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                   False
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                 0.01
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_2.npy
# results_filename       ./data/results/results_2.npy
# Name: 2, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                       1
# restrict_energy                                   1
# inner_steps                                      10
# stepsize_meta                                  0.01
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                    True
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                 0.03
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_3.npy
# results_filename       ./data/results/results_3.npy
# Name: 3, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                       1
# restrict_energy                                   1
# inner_steps                                       5
# stepsize_meta                                  0.01
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                    True
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                  0.1
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_4.npy
# results_filename       ./data/results/results_4.npy
# Name: 4, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                       1
# restrict_energy                                   1
# inner_steps                                       5
# stepsize_meta                                  0.01
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                   False
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                  0.1
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_5.npy
# results_filename       ./data/results/results_5.npy
# Name: 5, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                       1
# restrict_energy                                   1
# inner_steps                                      10
# stepsize_meta                                  0.01
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                   False
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                  0.1
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_6.npy
# results_filename       ./data/results/results_6.npy
# Name: 6, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                       1
# restrict_energy                                   1
# inner_steps                                      10
# stepsize_meta                                  0.03
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                    True
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                 0.01
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_7.npy
# results_filename       ./data/results/results_7.npy
# Name: 7, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                       1
# restrict_energy                                   1
# inner_steps                                       5
# stepsize_meta                                  0.03
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                    True
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                 0.03
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_8.npy
# results_filename       ./data/results/results_8.npy
# Name: 8, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                          250
# learner                                   modulator
# inner_batch_size                                256
# std_explore                                       1
# restrict_energy                                   1
# inner_steps                                       5
# stepsize_meta                                  0.03
# SNR_db                                          8.4
# bits_per_symbol                                   2
# optimizer                                       sgd
# first_order                                   False
# seed                                            777
# model                                    MAMLNeural
# hidden_layers                              [50, 50]
# nshots                                           10
# meta-alg                                       MAML
# stepsize_inner                                 0.03
# outer_batch_size                               1024
# ntasks                                           16
# loss_function                                   ppo
# model_filename      ./data/saved_models/agent_9.npy
# results_filename       ./data/results/results_9.npy
# Name: 9, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                           250
# learner                                    modulator
# inner_batch_size                                 256
# std_explore                                        1
# restrict_energy                                    1
# inner_steps                                       10
# stepsize_meta                                   0.03
# SNR_db                                           8.4
# bits_per_symbol                                    2
# optimizer                                        sgd
# first_order                                    False
# seed                                             777
# model                                     MAMLNeural
# hidden_layers                               [50, 50]
# nshots                                            10
# meta-alg                                        MAML
# stepsize_inner                                  0.03
# outer_batch_size                                1024
# ntasks                                            16
# loss_function                                    ppo
# model_filename      ./data/saved_models/agent_10.npy
# results_filename       ./data/results/results_10.npy
# Name: 10, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                           250
# learner                                    modulator
# inner_batch_size                                 256
# std_explore                                      0.3
# restrict_energy                                    1
# inner_steps                                       10
# stepsize_meta                                   0.03
# SNR_db                                           8.4
# bits_per_symbol                                    2
# optimizer                                        sgd
# first_order                                     True
# seed                                             777
# model                                     MAMLNeural
# hidden_layers                               [50, 50]
# nshots                                            10
# meta-alg                                        MAML
# stepsize_inner                                   0.1
# outer_batch_size                                1024
# ntasks                                            16
# loss_function                                    ppo
# model_filename      ./data/saved_models/agent_11.npy
# results_filename       ./data/results/results_11.npy
# Name: 11, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                           250
# learner                                    modulator
# inner_batch_size                                 256
# std_explore                                      0.3
# restrict_energy                                    1
# inner_steps                                        5
# stepsize_meta                                    0.1
# SNR_db                                           8.4
# bits_per_symbol                                    2
# optimizer                                        sgd
# first_order                                     True
# seed                                             777
# model                                     MAMLNeural
# hidden_layers                               [50, 50]
# nshots                                            10
# meta-alg                                        MAML
# stepsize_inner                                  0.01
# outer_batch_size                                1024
# ntasks                                            16
# loss_function                                    ppo
# model_filename      ./data/saved_models/agent_12.npy
# results_filename       ./data/results/results_12.npy
# Name: 12, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                           250
# learner                                    modulator
# inner_batch_size                                 256
# std_explore                                      0.3
# restrict_energy                                    1
# inner_steps                                        5
# stepsize_meta                                    0.1
# SNR_db                                           8.4
# bits_per_symbol                                    2
# optimizer                                        sgd
# first_order                                    False
# seed                                             777
# model                                     MAMLNeural
# hidden_layers                               [50, 50]
# nshots                                            10
# meta-alg                                        MAML
# stepsize_inner                                  0.01
# outer_batch_size                                1024
# ntasks                                            16
# loss_function                                    ppo
# model_filename      ./data/saved_models/agent_13.npy
# results_filename       ./data/results/results_13.npy
# Name: 13, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                           250
# learner                                    modulator
# inner_batch_size                                 256
# std_explore                                      0.3
# restrict_energy                                    1
# inner_steps                                       10
# stepsize_meta                                    0.1
# SNR_db                                           8.4
# bits_per_symbol                                    2
# optimizer                                        sgd
# first_order                                    False
# seed                                             777
# model                                     MAMLNeural
# hidden_layers                               [50, 50]
# nshots                                            10
# meta-alg                                        MAML
# stepsize_inner                                  0.01
# outer_batch_size                                1024
# ntasks                                            16
# loss_function                                    ppo
# model_filename      ./data/saved_models/agent_14.npy
# results_filename       ./data/results/results_14.npy
# Name: 14, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer
# Modulator neural initialized with SGD optimizer.
# Parameters:
# epochs                                           250
# learner                                    modulator
# inner_batch_size                                 256
# std_explore                                      0.3
# restrict_energy                                    1
# inner_steps                                       10
# stepsize_meta                                    0.1
# SNR_db                                           8.4
# bits_per_symbol                                    2
# optimizer                                        sgd
# first_order                                     True
# seed                                             777
# model                                     MAMLNeural
# hidden_layers                               [50, 50]
# nshots                                            10
# meta-alg                                        MAML
# stepsize_inner                                  0.03
# outer_batch_size                                1024
# ntasks                                            16
# loss_function                                    ppo
# model_filename      ./data/saved_models/agent_15.npy
# results_filename       ./data/results/results_15.npy
# Name: 15, dtype: object
# Demodulator classic initialized WITHOUT an optimizer
# Demodulator classic initialized WITHOUT an optimizer

# %%
bps = 4
# snr = 12
# sm = 1e-2
query = {'bits_per_symbol': bps, 'learner': 'modulator'}#, 'SNR_db': snr, 'stepsize_meta': sm}
response = DF.search_rows(query)
print("{} results found".format(len(response)))
compute_test_bers(response, query)

# %%
bps = 6
# snr = 12
# sm = 1e-2
query = {'bits_per_symbol': bps, 'learner': 'modulator'}#, 'SNR_db': snr, 'stepsize_meta': sm}
response = DF.search_rows(query)
print("{} results found".format(len(response)))
compute_test_bers(response, query)
